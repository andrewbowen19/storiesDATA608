# %% [markdown]
# # Story 3
#
# *Do stricter gun laws reduce firearm gun deaths?*

# %%
import requests
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import folium

# %% [markdown]
# ## Datasources
#
# We can use the below NCHS API endpoint to see cause of death rates per state *per quarter* in the US. This will be a good starting point as we look to visualize per state
#
# - [NCHS Leading Cause of Deathe API Endpoint](https://dev.socrata.com/foundry/data.cdc.gov/bi63-dtpu)

# %%
# Grabbing data from API endpoint
response = requests.get("https://data.cdc.gov/resource/489q-934x.json").json()

# %%
# Write response to pandas dataframe
df = pd.json_normalize(response)
df.head()
# Out:
#   year_and_quarter                    time_period  \
# 0          2020 Q1  12 months ending with quarter
# 1          2020 Q1  12 months ending with quarter
# 2          2020 Q1  12 months ending with quarter
# 3          2020 Q1  12 months ending with quarter
# 4          2020 Q1  12 months ending with quarter
#
#                         cause_of_death     rate_type                unit  \
# 0                           All causes  Age-adjusted  Deaths per 100,000
# 1                    Alzheimer disease  Age-adjusted  Deaths per 100,000
# 2                             COVID-19  Age-adjusted  Deaths per 100,000
# 3                               Cancer  Age-adjusted  Deaths per 100,000
# 4  Chronic liver disease and cirrhosis  Age-adjusted  Deaths per 100,000
#
#   rate_overall rate_sex_female rate_sex_male rate_alaska rate_alabama  ...  \
# 0        718.6           605.1           851       691.2        898.2  ...
# 1         29.8            33.6          23.8        24.1         44.6  ...
# 2          1.7             1.2           2.3         NaN          0.7  ...
# 3        145.7             126         172.2       141.3        159.9  ...
# 4         11.5             8.1          15.2          16         13.7  ...
#
#   rate_age_1_4 rate_age_5_14 rate_age_15_24 rate_age_25_34 rate_age_35_44  \
# 0          NaN           NaN            NaN            NaN            NaN
# 1          NaN           NaN            NaN            NaN            NaN
# 2          NaN           NaN            NaN            NaN            NaN
# 3          NaN           NaN            NaN            NaN            NaN
# 4          NaN           NaN            NaN            NaN            NaN
#
#   rate_age_45_54 rate_age_55_64 rate_65_74 rate_age_75_84 rate_age_85_plus
# 0            NaN            NaN        NaN            NaN              NaN
# 1            NaN            NaN        NaN            NaN              NaN
# 2            NaN            NaN        NaN            NaN              NaN
# 3            NaN            NaN        NaN            NaN              NaN
# 4            NaN            NaN        NaN            NaN              NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ## Data Wrangling

# %%
# Pulling out only firearm deaths that are age-adjusted
df = df.loc[(df.cause_of_death == "Firearm-related injury") & (df.rate_type == "Age-adjusted") & (df.time_period=="3-month period")]

# %%
# Select only needed columns and transpose our data
state_cols = ['year_and_quarter', 'rate_alaska', 'rate_alabama', 'rate_arkansas', 'rate_arizona',
              'rate_california', 'rate_colorado', 'rate_connecticut',
              'rate_district_of_columbia', 'rate_delaware', 'rate_florida',
              'rate_georgia', 'rate_hawaii', 'rate_iowa', 'rate_idaho',
              'rate_illinois', 'rate_indiana', 'rate_kansas', 'rate_kentucky',
              'rate_louisiana', 'rate_massachusetts', 'rate_maryland', 'rate_maine',
              'rate_michigan', 'rate_minnesota', 'rate_missouri', 'rate_mississippi',
              'rate_montana', 'rate_north_carolina', 'rate_north_dakota',
              'rate_nebraska', 'rate_new_hampshire', 'rate_new_jersey',
              'rate_new_mexico', 'rate_nevada', 'rate_new_york', 'rate_ohio',
              'rate_oklahoma', 'rate_oregon', 'rate_pennsylvania',
              'rate_rhode_island', 'rate_south_carolina', 'rate_south_dakota',
              'rate_tennessee', 'rate_texas', 'rate_utah', 'rate_virginia',
              'rate_vermont', 'rate_washington', 'rate_wisconsin',
              'rate_west_virginia', 'rate_wyoming', 'rate_overall']
df = df[state_cols].transpose()
df.head()
# Out:
#                       31       75       119      163      207      251  \
# year_and_quarter  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  2021 Q2
# rate_alaska          21.4     20.2     26.4     26.1     19.4     28.8
# rate_alabama           23     23.4     24.9       23     26.4     27.6
# rate_arkansas        20.8     27.1     21.3     21.1     22.4     27.2
# rate_arizona         15.9     15.4     18.4     16.9     16.7     18.4
#
#                       295      339      383      427      471      515
# year_and_quarter  2021 Q3  2021 Q4  2022 Q1  2022 Q2  2022 Q3  2022 Q4
# rate_alaska          24.8     27.9     22.5     20.4     24.5      NaN
# rate_alabama         26.4     25.2     24.1     26.8       28      NaN
# rate_arkansas        21.1     22.4     19.2       25     23.4      NaN
# rate_arizona           19     19.1     18.7     22.7     20.8      NaN

# %%
# Clean up column names and types
df.columns = df.iloc[0]

# %%
# Clean up state names and set index
df["state"] = [s.replace("_", " ").replace("rate", "").title().strip() for s in df.index.values]
df = df.set_index('state')
df.head()
# Out:
# year_and_quarter  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  2021 Q2  \
# state
# Year And Quarter  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  2021 Q2
# Alaska               21.4     20.2     26.4     26.1     19.4     28.8
# Alabama                23     23.4     24.9       23     26.4     27.6
# Arkansas             20.8     27.1     21.3     21.1     22.4     27.2
# Arizona              15.9     15.4     18.4     16.9     16.7     18.4
#
# year_and_quarter  2021 Q3  2021 Q4  2022 Q1  2022 Q2  2022 Q3  2022 Q4
# state
# Year And Quarter  2021 Q3  2021 Q4  2022 Q1  2022 Q2  2022 Q3  2022 Q4
# Alaska               24.8     27.9     22.5     20.4     24.5      NaN
# Alabama              26.4     25.2     24.1     26.8       28      NaN
# Arkansas             21.1     22.4     19.2       25     23.4      NaN
# Arizona                19     19.1     18.7     22.7     20.8      NaN

# %%
# Resetting our index and enforcing typing on state names
df = df.reset_index()
df = df.iloc[1:]
df["state"] = df["state"].str.title().astype(str)

for c in ['2020 Q1', '2020 Q2', '2020 Q3', '2020 Q4', '2021 Q1',
       '2021 Q2', '2021 Q3', '2021 Q4', '2022 Q1', '2022 Q2', '2022 Q3',
       '2022 Q4']:
    df[c] = df[c].astype(float)

df.head()
# Out:
# year_and_quarter       state  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  \
# 1                     Alaska     21.4     20.2     26.4     26.1     19.4
# 2                    Alabama     23.0     23.4     24.9     23.0     26.4
# 3                   Arkansas     20.8     27.1     21.3     21.1     22.4
# 4                    Arizona     15.9     15.4     18.4     16.9     16.7
# 5                 California      7.5      7.9      9.2      9.4      8.7
#
# year_and_quarter  2021 Q2  2021 Q3  2021 Q4  2022 Q1  2022 Q2  2022 Q3  \
# 1                    28.8     24.8     27.9     22.5     20.4     24.5
# 2                    27.6     26.4     25.2     24.1     26.8     28.0
# 3                    27.2     21.1     22.4     19.2     25.0     23.4
# 4                    18.4     19.0     19.1     18.7     22.7     20.8
# 5                     9.1      9.5      8.5      8.3      8.9      9.4
#
# year_and_quarter  2022 Q4
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN

# %% [markdown]
# ## Data Visualization
# Let's first plot the rate of firearm related homo

# %%
df_sorted = df.sort_values("2022 Q3", ascending=False)
order = df.groupby("state").sum().sort_values(['2022 Q3'], ascending=False).index

# Plot a sorted bar chart of deaths per 100k
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(data=df, x="2022 Q3", y="state", order=order, orient="h")
ax.set_xlabel("Firearm deaths per 100k residents")
ax.set_ylabel("State")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Geometry Data for Later Choropleths
# Grabbed this GeoJSON from [plotly datasets](https://github.com/plotly/datasets)

# %%
# Read in GeoJSON containing state boundary data
geojson_path = "./data/us-states.json"
states = gpd.read_file("./data/us-states.json")
states['state'] = states['name'].str.title().astype(str)
states.head()
# Out:
#    id        name                                           geometry  \
# 0  AL     Alabama  POLYGON ((-87.35930 35.00118, -85.60667 34.984...
# 1  AK      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2  AZ     Arizona  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 3  AR    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  CA  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...
#
#         state
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California

# %%
# Convert to geopandas dataframe
gdf = gpd.GeoDataFrame(df)

gdf.head()
# Out:
# year_and_quarter       state  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  \
# 1                     Alaska     21.4     20.2     26.4     26.1     19.4
# 2                    Alabama     23.0     23.4     24.9     23.0     26.4
# 3                   Arkansas     20.8     27.1     21.3     21.1     22.4
# 4                    Arizona     15.9     15.4     18.4     16.9     16.7
# 5                 California      7.5      7.9      9.2      9.4      8.7
#
# year_and_quarter  2021 Q2  2021 Q3  2021 Q4  2022 Q1  2022 Q2  2022 Q3  \
# 1                    28.8     24.8     27.9     22.5     20.4     24.5
# 2                    27.6     26.4     25.2     24.1     26.8     28.0
# 3                    27.2     21.1     22.4     19.2     25.0     23.4
# 4                    18.4     19.0     19.1     18.7     22.7     20.8
# 5                     9.1      9.5      8.5      8.3      8.9      9.4
#
# year_and_quarter  2022 Q4
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN

# %%
# Join Firearm data to geometry data
dat = gdf.merge(states, on="state", how='left')
dat = dat.iloc[1:]
dat.head()
# Out:
#         state  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  2021 Q2  2021 Q3  \
# 1     Alabama     23.0     23.4     24.9     23.0     26.4     27.6     26.4
# 2    Arkansas     20.8     27.1     21.3     21.1     22.4     27.2     21.1
# 3     Arizona     15.9     15.4     18.4     16.9     16.7     18.4     19.0
# 4  California      7.5      7.9      9.2      9.4      8.7      9.1      9.5
# 5    Colorado     14.2     16.3     17.9     13.2     18.2     18.0     15.4
#
#    2021 Q4  2022 Q1  2022 Q2  2022 Q3  2022 Q4  id        name  \
# 1     25.2     24.1     26.8     28.0      NaN  AL     Alabama
# 2     22.4     19.2     25.0     23.4      NaN  AR    Arkansas
# 3     19.1     18.7     22.7     20.8      NaN  AZ     Arizona
# 4      8.5      8.3      8.9      9.4      NaN  CA  California
# 5     19.5     15.0     16.8     17.2      NaN  CO    Colorado
#
#                                             geometry
# 1  POLYGON ((-87.35930 35.00118, -85.60667 34.984...
# 2  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 3  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 4  POLYGON ((-123.23326 42.00619, -122.37885 42.0...
# 5  POLYGON ((-107.91973 41.00391, -105.72895 40.9...

# %%
# Convert types

# %%
# Getting state data
state_geo = requests.get(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/us_states.json"
).json()

# %% [markdown]
# We can use [Folium's `choropleth` function](https://python-visualization.github.io/folium/latest/getting_started.html) to make this heatmap

# %%
m = folium.Map(location=[48, -102], zoom_start=3)
folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data=dat,
    columns=["id", "2022 Q3"],
    key_on="feature.id",
    fill_color="YlGn",
    legend_name="Firearm Deaths per 100k inhabitants",
).add_to(m)

# Add title and kicker
title_html = "<h4>Firearm Deaths per 100,000 inhabitants - USA Q3 2022</h4>"
subtitle_html = "<p>States with higher rates of firearm death tend to also have less restrictive gun laws</p>"


m.get_root().html.add_child(folium.Element(title_html)).add_child(folium.Element(subtitle_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcef98d9e3d96a1c16b1310dfad7955d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h4&gt;Firearm Deaths per 100,000 inhabitants - USA Q3 2022&lt;/h4&gt;
#     &lt;p&gt;States with higher rates of firearm death tend to also have less restrictive gun laws&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcef98d9e3d96a1c16b1310dfad7955d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcef98d9e3d96a1c16b1310dfad7955d = L.map(
#                 &quot;map_bcef98d9e3d96a1c16b1310dfad7955d&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10b31ef7fc5c50b1a880cbc7e7bc5b65 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcef98d9e3d96a1c16b1310dfad7955d);
#
#
#             var choropleth_d07236d9893122a2fc7a9b65ab44dde1 = L.featureGroup(
#                 {}
#             ).addTo(map_bcef98d9e3d96a1c16b1310dfad7955d);
#
#
#         function geo_json_6341f5b2b987b70a1a4f849bb48935cb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;MS&quot;: case &quot;NM&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CO&quot;: case &quot;GA&quot;: case &quot;IN&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;NV&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AR&quot;: case &quot;LA&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CT&quot;: case &quot;ME&quot;: case &quot;MN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;MA&quot;: case &quot;NJ&quot;: case &quot;NY&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6341f5b2b987b70a1a4f849bb48935cb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6341f5b2b987b70a1a4f849bb48935cb = L.geoJson(null, {
#                 onEachFeature: geo_json_6341f5b2b987b70a1a4f849bb48935cb_onEachFeature,
#
#                 style: geo_json_6341f5b2b987b70a1a4f849bb48935cb_styler,
#         });
#
#         function geo_json_6341f5b2b987b70a1a4f849bb48935cb_add (data) {
#             geo_json_6341f5b2b987b70a1a4f849bb48935cb
#                 .addData(data)
#                 .addTo(choropleth_d07236d9893122a2fc7a9b65ab44dde1);
#         }
#             geo_json_6341f5b2b987b70a1a4f849bb48935cb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416,

# %% [markdown]
# [Giffords also posts rankings of the relative strength of state's gun laws](https://giffords.org/lawcenter/resources/scorecard/). This can be a helpful way for us to visualize where gun laws are more or less restrictvie in the US, which can help us to answer the question of whether they correlate with a state's gun death rate.

# %%
# Read in rankings
ranks = pd.read_html("https://giffords.org/lawcenter/resources/scorecard/")[0]

# Clean up relevant columns
ranks['state'] = ranks['State'].astype(str)
ranks = ranks.loc[ranks['Gun Law Strength  (Ranked)'] != "Share"]
ranks['gun_law_strength_ranking'] = ranks['Gun Law Strength  (Ranked)'].astype(int)

# Merge to geographic data
ranks = gpd.GeoDataFrame(ranks).merge(states, how="left", on="state")
ranks.head()
# Out:
#   Gun Law Strength  (Ranked)       State Grade Gun Death Rate  (Ranked)  \
# 0                         38     Alabama     F                        4
# 1                         41      Alaska     F                        6
# 2                         42     Arizona     F                       17
# 3                         50    Arkansas     F                        8
# 4                          1  California     A                       43
#
#   Gun Death Rate  (per 100K)       state  gun_law_strength_ranking  id  \
# 0                       26.4     Alabama                        38  AL
# 1                       25.2      Alaska                        41  AK
# 2                       18.3     Arizona                        42  AZ
# 3                       23.3    Arkansas                        50  AR
# 4                        9.0  California                         1  CA
#
#          name                                           geometry
# 0     Alabama  POLYGON ((-87.35930 35.00118, -85.60667 34.984...
# 1      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2     Arizona  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 3    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
# Plotting gun law strength
m1 = folium.Map(location=[48, -102], zoom_start=3)
folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data=ranks,
    columns=["id", "gun_law_strength_ranking"],
    key_on="feature.id",
    fill_color="YlGn",
    legend_name="Gun Law Strength Ranking",
).add_to(m1)

# Add title and kicker
title_html = '''
             <h4>Gun Law Ratings per state (Giffords)</h4>
             ''' 
subtitle_html = "<p>States with stronger gun laws tend to have fewer firearm deaths per capita.</p>"


m1.get_root().html.add_child(folium.Element(title_html)).add_child(folium.Element(subtitle_html))

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38c7e2b41d28e6bec4796f919c09fde7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h4&gt;Gun Law Ratings per state (Giffords)&lt;/h4&gt;
#
#     &lt;p&gt;States with stronger gun laws tend to have fewer firearm deaths per capita.&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38c7e2b41d28e6bec4796f919c09fde7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38c7e2b41d28e6bec4796f919c09fde7 = L.map(
#                 &quot;map_38c7e2b41d28e6bec4796f919c09fde7&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88454dd04a2835939d3e8d0450617da9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38c7e2b41d28e6bec4796f919c09fde7);
#
#
#             var choropleth_9438016152bcd6bdb572de0ff43c728d = L.featureGroup(
#                 {}
#             ).addTo(map_38c7e2b41d28e6bec4796f919c09fde7);
#
#
#         function geo_json_f17fcd7d1cc1e544e6a5630f16320f18_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;GA&quot;: case &quot;MT&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;TN&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;AR&quot;: case &quot;ID&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;SD&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CO&quot;: case &quot;DE&quot;: case &quot;MI&quot;: case &quot;NV&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;VA&quot;: case &quot;WA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;: case &quot;MN&quot;: case &quot;NE&quot;: case &quot;NM&quot;: case &quot;NC&quot;: case &quot;OH&quot;: case &quot;VT&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;IN&quot;: case &quot;IA&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;NH&quot;: case &quot;SC&quot;: case &quot;TX&quot;: case &quot;UT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f17fcd7d1cc1e544e6a5630f16320f18_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f17fcd7d1cc1e544e6a5630f16320f18 = L.geoJson(null, {
#                 onEachFeature: geo_json_f17fcd7d1cc1e544e6a5630f16320f18_onEachFeature,
#
#                 style: geo_json_f17fcd7d1cc1e544e6a5630f16320f18_styler,
#         });
#
#         function geo_json_f17fcd7d1cc1e544e6a5630f16320f18_add (data) {
#             geo_json_f17fcd7d1cc1e544e6a5630f16320f18
#                 .addData(data)
#                 .addTo(choropleth_9438016152bcd6bdb572de0ff43c728d);
#         }
#             geo_json_f17fcd7d1cc1e544e6a5630f16320f18_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-8

# %% [markdown]
# We can see states with higher rankings (lighter shades such as California, New York, etc.) on the above choropleth also tend to have lower death rates from firearms. So there is some weight to the theory of stricter gun laws can have a positive impact on lowering firearm-related deaths

# %% [markdown]
# ### Likert Scale
# We can create a [5-point Likert Scale](https://www.simplypsychology.org/likert-scale.html) in order to

# %%
# COllapse grades into 5 bins
ranks['grade'] = ranks['Grade'].str.replace("+", "")
ranks['grade'] = ranks['grade'].str.replace("-", "")

likert = ranks.groupby("grade")["grade"].count()
likert
# Out:
# grade
# A     8
# B     7
# C     8
# D     1
# F    26
# Name: grade, dtype: int64

# %%
f, ax = plt.subplots(figsize=(10,10))
sns.barplot(ax=ax, data=likert)

# Style the likert scale plot
plt.suptitle("Number of States per Gun Law Rating", fontsize=18)
ax.set_title("Most American states are rated as failing on gun safety, according to Giffords")
ax.set_xlabel("Gun Law Grade (Giffords)")
ax.set_ylabel("Number of US States")
# Out:
# Text(0, 0.5, 'Number of US States')

# %% [markdown]
# ## Conclusion
#
# Unfortunately, our likert scale based on Gifford ratings shows many US States as having a "failing" record on implementing proper gun laws. We can see the longer-tail effects of these policies in the firearm death rate choropleth above, as states with looser gun laws tend to see more firearm realted injury and deaths.
#
# Further work could include more study over time of the effects of looser gun laws, as the NCHS API endpoint used only provided data for the past 3 years.,
